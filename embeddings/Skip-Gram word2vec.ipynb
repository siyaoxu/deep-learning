# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
t = 1e-5
word_count = Counter(int_words)
word_freq = {}
p_word_rej = {}
for key in word_count:
    word_freq[key] = word_count[key]/len(int_words)
    p_word_rej[key] = 1 - np.sqrt(t/word_freq[key])

# %%
p_word_rej
# Out:
# {0: 0.98746376577740469,
#  1: 0.98323781193133519,
#  2: 0.97999073790717206,
#  3: 0.9798728800896066,
#  4: 0.97883018546630463,
#  5: 0.97737536238795875,
#  6: 0.97703829909505446,
#  7: 0.9749098434772655,
#  8: 0.97419150710880509,
#  9: 0.97057421364733043,
#  10: 0.96982141987906356,
#  11: 0.9644267615025448,
#  12: 0.96351147714751806,
#  13: 0.96247268826339005,
#  14: 0.96219477853599333,
#  15: 0.96204472263650453,
#  16: 0.96187743001877457,
#  17: 0.96154632989244049,
#  18: 0.96137889308882907,
#  19: 0.96097176318217992,
#  20: 0.96073294615313531,
#  21: 0.95958921707063671,
#  22: 0.95909322225651139,
#  23: 0.95822946278846788,
#  24: 0.95724475646993612,
#  25: 0.95331273030870545,
#  26: 0.95230716554740003,
#  27: 0.95215589262593403,
#  28: 0.95081253586052672,
#  29: 0.9483811590967528,
#  30: 0.94809934803293527,
#  31: 0.9478273496542321,
#  32: 0.946752525433321,
#  33: 0.94482236303063571,
#  34: 0.94471529837599,
#  35: 0.94420017490649355,
#  36: 0.93867750129023297,
#  37: 0.93845161192836102,
#  38: 0.93518956429284583,
#  39: 0.93467262506280524,
#  40: 0.93362858054996889,
#  41: 0.93131498849887417,
#  42: 0.92828462725810013,
#  43: 0.92725685893570531,
#  44: 0.92488923411459367,
#  45: 0.92390884227957237,
#  46: 0.92356716853581156,
#  47: 0.92303703602880982,
#  48: 0.92295354500200544,
#  49: 0.92025288979511088,
#  50: 0.92024376697746335,
#  51: 0.91922073243909708,
#  52: 0.91915112240321317,
#  53: 0.91893482097105594,
#  54: 0.91734002958971483,
#  55: 0.91679808087580228,
#  56: 0.91662663211107231,
#  57: 0.91622947635923757,
#  58: 0.91434765844710708,
#  59: 0.91429109610748627,
#  60: 0.91113976401977348,
#  61: 0.91006475954266375,
#  62: 0.90976013488915453,
#  63: 0.90974471209576169,
#  64: 0.9096011217876584,
#  65: 0.90836266136306265,
#  66: 0.90742346330366108,
#  67: 0.90680612742203881,
#  68: 0.90658455868029486,
#  69: 0.90582273829350224,
#  70: 0.90359807809144665,
#  71: 0.90259437572906309,
#  72: 0.90241381216729244,
#  73: 0.90202428974620652,
#  74: 0.90162435828281684,
#  75: 0.89838628256769837,
#  76: 0.89744884914797107,
#  77: 0.89704561501045865,
#  78: 0.89650824877821622,
#  79: 0.89497294105469938,
#  80: 0.8943174685407228,
#  81: 0.89425018076024387,
#  82: 0.89346158058149261,
#  83: 0.89321788929128998,
#  84: 0.89303126791127208,
#  85: 0.89272174699235118,
#  86: 0.89251017822282175,
#  87: 0.89244683603418784,
#  88: 0.89142939558504453,
#  89: 0.89088831703019855,
#  90: 0.88834510581208903,
#  91: 0.88799296064432998,
#  92: 0.88666830066537394,
#  93: 0.88630440367506491,
#  906: 0.7064695606897764,
#  907: 0.70639372282794755,
#  908: 0.70631782615428174,
#  909: 0.70601364981811776,
#  910: 0.70578489630132624,
#  911: 0.70570852638344062,
#  912: 0.70555560796646166,
#  913: 0.70555560796646166,
#  914: 0.70540245092513798,
#  915: 0.70532578272629287,
#  916: 0.70517226658288945,
#  917: 0.70509541848216639,
#  918: 0.70494154183119573,
#  919: 0.7048645131239264,
#  920: 0.70478742405721373,
#  921: 0.7047102745521876,
#  922: 0.70463306452983321,
#  923: 0.70455579391099132,
#  924: 0.70424610388247744,
#  925: 0.70409089322045926,
#  926: 0.70401319619751612,
#  927: 0.70401319619751612,
#  928: 0.70393543793956037,
#  929: 0.70393543793956037,
#  930: 0.70385761836611482,
#  931: 0.70370179495010521,
#  932: 0.70362379094584482,
#  933: 0.70346759793945357,
#  934: 0.70338940877473,
#  935: 0.70338940877473,
#  936: 0.70331115772700925,
#  937: 0.70331115772700925,
#  938: 0.70307603246838668,
#  939: 0.70291897137962922,
#  940: 0.70276166078951019,
#  941: 0.70268291172488562,
#  942: 0.70268291172488562,
#  943: 0.70236728840005025,
#  944: 0.70220909933142772,
#  945: 0.70212991015287907,
#  946: 0.70149411414699225,
#  947: 0.70141435305382449,
#  948: 0.70133452798972051,
#  949: 0.70117468560631624,
#  950: 0.70101458631039781,
#  951: 0.70093444010504735,
#  952: 0.70085422941300701,
#  953: 0.70069361422259613,
#  954: 0.70061320955068829,
#  955: 0.70053274004501553,
#  956: 0.70045220561840038,
#  957: 0.70037160618350125,
#  958: 0.70037160618350125,
#  959: 0.70029094165281203,
#  960: 0.70021021193866173,
#  961: 0.70004855660846621,
#  962: 0.69988663948823038,
#  963: 0.69988663948823038,
#  964: 0.69980558253590508,
#  965: 0.69964327140349214,
#  966: 0.69915475376661462,
#  967: 0.69915475376661462,
#  968: 0.69907310218518626,
#  969: 0.69899138408515582,
#  970: 0.69890959937615738,
#  971: 0.69858179263712761,
#  972: 0.69808806878884311,
#  973: 0.69792295423933259,
#  974: 0.69750897974639847,
#  975: 0.69750897974639847,
#  976: 0.69717657193153659,
#  977: 0.69717657193153659,
#  978: 0.69667589907150207,
#  979: 0.69659221191280429,
#  980: 0.6965084554479688,
#  981: 0.69642462958128193,
#  982: 0.69634073421684528,
#  983: 0.69625676925857438,
#  984: 0.69617273461019891,
#  985: 0.69617273461019891,
#  986: 0.69608863017526201,
#  987: 0.6960044558571199,
#  988: 0.69575151263420731,
#  989: 0.69566705781304816,
#  990: 0.69566705781304816,
#  991: 0.69558253262264258,
#  992: 0.69532853385723759,
#  993: 0.69507389823724197,
#  994: 0.69473338880477842,
#  995: 0.69464808305735526,
#  996: 0.69447725679675232,
#  997: 0.69439173608319404,
#  998: 0.69413474240309125,
#  999: 0.69413474240309125,
#  ...}

# %%
train_words = [int_word for int_word in int_words if p_word_rej[int_word]<np.random.uniform()]

# %%
print('Subsampled words:{}'.format(len(train_words)))
print("Unique sumsampled words: {}".format(len(set(train_words))))
# Out:
# Subsampled words:4628699
# Unique sumsampled words: 63641

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = np.random.randint(1,window_size)
    return words[idx-r:idx+r+1]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,shape = (None))
    labels = tf.placeholder(tf.int32,shape = (None,1))

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding),-1,1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding ,inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
# import math
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding],
                      stddev=1.0 / np.sqrt(n_embedding)))# create softmax weight matrix here
    softmax_b =  tf.Variable(tf.zeros([n_vocab]))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,num_sampled=n_sampled,num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.4605 0.1826 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.3583 0.1834 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.1545 0.1825 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.1914 0.1825 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.0928 0.1820 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.0543 0.1842 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.0559 0.1833 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.0080 0.1844 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.9593 0.1852 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.8816 0.1873 sec/batch
# Nearest to after: cleveland, lix, capablanca, eridanus, conte, berwick, unexpired, rrna,
# Nearest to into: kword, local, explicated, reinforced, commence, crossings, estimators, council,
# Nearest to history: tracking, aristocratic, zealot, colossal, synthetics, jourdain, secretions, holmes,
# Nearest to by: whiteman, enters, dendrites, wholesome, homeschool, conquistadors, enough, vvd,
# Nearest to many: demands, crossing, indri, learned, mnt, multilevel, alia, talkers,
# Nearest to an: rearwards, debauchery, ladd, jean, expels, courthouse, circe, lip,
# Nearest to this: za, melanesian, profited, vigor, aarseth, anfa, potters, fuse,
# Nearest to his: heartland, dallas, sketchy, prosecution, nibelungenlied, abercrombie, kalimantan, korean,
# Nearest to woman: refuting, malfeasance, residenz, pour, facemask, divided, sudanic, manufacture,
# Nearest to grand: beasts, welwyn, abducted, mesozoic, pervaded, ratiocinator, regiment, discover,
# Nearest to shows: nintendo, validation, persians, leng, head, poem, stateside, mover,
# Nearest to brother: castletown, hamel, fallopian, humorist, leadership, rejoiced, terminally, watling,
# Nearest to articles: assets, sigurd, merton, rediscovered, totalled, tithes, tolstoy, gentlemen,
# Nearest to running: chatter, buck, acknowledges, franti, roshan, porpoises, fares, possible,
# Nearest to marriage: mala, alternated, regulus, hardened, runge, oran, cosmography, ger,
# Nearest to governor: tableaux, gutted, cabriolet, tupi, invisibly, fedex, willard, confidentially,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.9472 0.1917 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.8569 0.1909 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.7732 0.1897 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.7129 0.1906 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.6655 0.1911 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.6404 0.1917 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.6151 0.1923 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.5789 0.1930 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.5201 0.1921 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.5115 0.1928 sec/batch
# Nearest to after: cleveland, lix, surroundings, nazareth, accordance, capablanca, expression, eridanus,
# Nearest to into: local, kword, reinforced, council, given, explicated, needed, crossings,
# Nearest to history: aristocratic, tracking, holmes, secretions, synthetics, metropolis, exodus, zealot,
# Nearest to by: enters, whiteman, enough, dendrites, wholesome, managers, dc, homeschool,
# Nearest to many: behaviour, learned, demands, club, tags, alia, multilevel, crossing,
# Nearest to an: jean, called, ladd, rearwards, month, differently, buzzing, queen,
# Nearest to this: profited, produced, attractive, favorite, anfa, career, fuse, za,
# Nearest to his: dallas, prosecution, heartland, korean, read, proximity, offenses, sketchy,
# Nearest to woman: divided, pour, refuting, manufacture, malfeasance, submarine, dd, sudanic,
# Nearest to grand: beasts, abducted, welwyn, brought, discover, regiment, geographic, subtitled,
# Nearest to shows: nintendo, validation, persians, head, poem, recurring, depend, bible,
# Nearest to brother: castletown, hamel, leadership, exports, fallopian, falsely, turn, humorist,
# Nearest to articles: assets, sigurd, rediscovered, liberty, merton, tithes, tolstoy, gentlemen,
# Nearest to running: buck, quickly, possible, acknowledges, chatter, franti, emotions, product,
# Nearest to marriage: mala, regulus, alternated, hardened, runge, decays, supermajority, ger,
# Nearest to governor: tableaux, gutted, tupi, invisibly, cabriolet, willard, tudes, fedex,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.4765 0.1964 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.4602 0.1942 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.4612 0.1937 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.4164 0.1935 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.3606 0.1935 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.3973 0.1936 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.3699 0.1944 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.3668 0.1942 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.3822 0.1940 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.3704 0.1940 sec/batch
# Nearest to after: cleveland, lix, surroundings, unwilling, capablanca, conte, berwick, nazareth,
# Nearest to into: local, kword, crossings, reinforced, explicated, experimentally, commence, council,
# Nearest to history: aristocratic, secretions, holmes, congressional, tracking, exodus, metropolis, jourdain,
# Nearest to by: enters, wholesome, whiteman, enthusiastic, enough, dendrites, managers, homeschool,
# Nearest to many: behaviour, club, alia, tags, multilevel, demands, mnt, hunted,
# Nearest to an: ladd, differently, rearwards, jean, courthouse, expels, month, lip,
# Nearest to this: za, profited, attractive, anfa, favorite, fuse, produced, gamma,
# Nearest to his: dallas, prosecution, heartland, sketchy, korean, offenses, proximity, notation,
# Nearest to woman: pour, refuting, divided, malfeasance, manufacture, submarine, dismiss, sudanic,
# Nearest to grand: beasts, welwyn, brought, geographic, discover, abducted, subtitled, stylistically,
# Nearest to shows: validation, nintendo, persians, recurring, wills, poem, sounding, head,
# Nearest to brother: exports, castletown, hamel, falsely, leadership, humorist, terminally, fallopian,
# Nearest to articles: assets, rediscovered, sigurd, tolstoy, tithes, gentlemen, merton, liberty,
# Nearest to running: buck, acknowledges, chatter, fares, quickly, possible, emotions, franti,
# Nearest to marriage: mala, alternated, hardened, supermajority, regulus, runge, ger, decays,
# Nearest to governor: tableaux, gutted, disabled, queen, willard, securing, invisibly, yearly,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.3887 0.1979 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.3333 0.1962 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.3106 0.1958 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.2966 0.1961 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.3283 0.1960 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.2917 0.1960 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.3038 0.1947 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.3055 0.1964 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.3069 0.1962 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.2673 0.1970 sec/batch
# Nearest to after: cleveland, lix, unwilling, nazareth, surroundings, capablanca, berwick, conte,
# Nearest to into: kword, crossings, seed, local, commence, reinforced, explicated, experimentally,
# Nearest to history: aristocratic, secretions, exodus, congressional, jourdain, zealot, holmes, metropolis,
# Nearest to by: enters, wholesome, whiteman, enthusiastic, crucible, dendrites, managers, homeschool,
# Nearest to many: behaviour, multilevel, alia, mnt, multicolored, gurus, hunted, magnitudes,
# Nearest to an: ladd, courthouse, expels, rearwards, differently, wednesday, jean, lip,
# Nearest to this: profited, za, anfa, fuse, vigor, melanesian, produced, anymore,
# Nearest to his: offenses, dallas, prosecution, heartland, sketchy, beauregard, korean, abercrombie,
# Nearest to woman: malfeasance, pour, refuting, divided, submarine, facemask, sudanic, dismiss,
# Nearest to grand: welwyn, mesozoic, beasts, lawn, brought, stylistically, geographic, discover,
# Nearest to shows: validation, nintendo, persians, recurring, leng, sounding, differentiable, wills,
# Nearest to brother: castletown, humorist, hamel, exports, terminally, rowman, fallopian, leadership,
# Nearest to articles: rediscovered, sigurd, assets, tithes, merton, tolstoy, gentlemen, mail,
# Nearest to running: acknowledges, buck, fares, chatter, wisconsin, franti, emotions, possible,
# Nearest to marriage: mala, alternated, ger, runge, supermajority, hardened, kamehameha, tavern,
# Nearest to governor: gutted, willard, queen, tableaux, disabled, invisibly, amputation, cabriolet,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.2614 0.1992 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.2441 0.1967 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.2043 0.1963 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.2387 0.1976 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.2225 0.1972 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.2425 0.1961 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.2170 0.1416 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.1837 0.1971 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.1259 0.1967 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.1205 0.1950 sec/batch
# Nearest to after: cleveland, lix, unwilling, berwick, nazareth, surroundings, capablanca, conte,
# Nearest to into: kword, crossings, reinforced, seed, local, commence, anabolic, explicated,
# Nearest to history: aristocratic, secretions, jourdain, zealot, exodus, congressional, salonika, emaciated,
# Nearest to by: enters, wholesome, whiteman, enthusiastic, crucible, haigh, asimov, homeschool,
# Nearest to many: behaviour, multilevel, magnitudes, mnt, multicolored, alia, talkers, linked,
# Nearest to an: ladd, expels, differently, courthouse, debauchery, rearwards, lip, solver,
# Nearest to this: za, profited, melanesian, anfa, vigor, attractive, fuse, favorite,
# Nearest to his: offenses, prosecution, beauregard, dallas, heartland, sketchy, abercrombie, commited,
# Nearest to woman: malfeasance, refuting, pour, facemask, divided, sudanic, submarine, residenz,
# Nearest to grand: mesozoic, welwyn, lawn, fishman, geographic, brought, beasts, ecologist,
# Nearest to shows: validation, nintendo, leng, sounding, persians, recurring, cdma, thummim,
# Nearest to brother: humorist, castletown, terminally, silvers, presbyterian, rowman, sothoth, rejoiced,
# Nearest to articles: rediscovered, sigurd, tithes, newcomb, merton, assets, tolstoy, wrangling,
# Nearest to running: fares, acknowledges, franti, buck, chatter, feldspar, possible, unspectacular,
# Nearest to marriage: mala, ger, alternated, oran, supermajority, runge, pontifex, kamehameha,
# Nearest to governor: gutted, queen, willard, amputation, cabriolet, nattiez, disabled, tudes,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.1215 0.1984 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.1036 0.1968 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.0531 0.1975 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.1276 0.1966 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.1130 0.1974 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.1048 0.1983 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.0674 0.1979 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.0327 0.1978 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.0461 0.1983 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.0159 0.1995 sec/batch
# Nearest to after: cleveland, lix, unwilling, berwick, conte, nazareth, bridgeport, catamaran,
# Nearest to into: kword, crossings, reinforced, anabolic, seed, explicated, commence, local,
# Nearest to history: aristocratic, secretions, jourdain, zealot, exodus, salonika, propagandists, metropolis,
# Nearest to by: enters, wholesome, crucible, whiteman, enthusiastic, haigh, linger, brighter,
# Nearest to many: behaviour, multilevel, mnt, magnitudes, multicolored, linked, counters, gurus,
# Nearest to an: ladd, differently, expels, rearwards, lip, solver, debauchery, courthouse,
# Nearest to this: za, profited, melanesian, anfa, vigor, attractive, gamma, captives,
# Nearest to his: offenses, prosecution, beauregard, sketchy, dallas, abercrombie, devonshire, commited,
# Nearest to woman: malfeasance, refuting, facemask, pour, sudanic, divided, trouser, residenz,
# Nearest to grand: welwyn, mesozoic, lawn, fishman, geographic, brought, paymaster, hanko,
# Nearest to shows: validation, nintendo, sounding, recurring, leng, behistun, differentiable, stateside,
# Nearest to brother: humorist, castletown, terminally, widow, rowman, sothoth, helen, rejoiced,
# Nearest to articles: rediscovered, tithes, sigurd, links, lithographica, merton, newcomb, tolstoy,
# Nearest to running: fares, acknowledges, franti, feldspar, possible, buck, roshan, porpoises,
# Nearest to marriage: mala, ger, holy, runge, pontifex, supermajority, oran, kamehameha,
# Nearest to governor: gutted, cabriolet, queen, cabinet, willard, amputation, disabled, nattiez,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.0481 0.2010 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.0254 0.1989 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.0373 0.1979 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.0092 0.1971 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 3.9920 0.1987 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.0493 0.1971 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.0028 0.1981 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 3.9837 0.1982 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.0140 0.1977 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 3.9627 0.1969 sec/batch
# Nearest to after: cleveland, lix, unwilling, berwick, rrna, nazareth, catamaran, capablanca,
# Nearest to into: kword, reinforced, crossings, anabolic, seed, commence, local, explicated,
# Nearest to history: aristocratic, jourdain, salonika, secretions, exodus, zealot, birger, chicano,
# Nearest to by: wholesome, enters, crucible, whiteman, enthusiastic, haigh, subjection, irix,
# Nearest to many: multilevel, behaviour, linked, multicolored, mnt, gurus, magnitudes, counters,
# Nearest to an: ladd, differently, expels, lip, externally, rearwards, courthouse, solver,
# Nearest to this: za, profited, vigor, melanesian, anfa, attractive, gamma, thereof,
# Nearest to his: offenses, prosecution, beauregard, sketchy, commited, scholasticus, silent, nero,
# Nearest to woman: malfeasance, refuting, facemask, pour, trouser, sudanic, divided, residenz,
# Nearest to grand: welwyn, mesozoic, lawn, fishman, barrington, brownlow, paymaster, ecologist,
# Nearest to shows: validation, recurring, nintendo, toonami, sounding, cdma, behistun, leng,
# Nearest to brother: humorist, castletown, widow, terminally, duchess, helen, rowman, sothoth,
# Nearest to articles: rediscovered, links, sigurd, lithographica, newcomb, tolstoy, tithes, merodach,
# Nearest to running: fares, franti, acknowledges, buck, feldspar, handled, runequest, roshan,
# Nearest to marriage: mala, holy, pontifex, allah, ger, runge, kamehameha, supermajority,
# Nearest to governor: gutted, cabinet, cabriolet, queen, amputation, willard, appointed, suburb,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 3.9675 0.2029 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.0106 0.1967 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 3.9517 0.1986 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 3.9630 0.1969 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.0282 0.1978 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 3.9977 0.1991 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.0077 0.1972 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 3.9891 0.1971 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 3.9436 0.1988 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 3.9343 0.2001 sec/batch
# Nearest to after: cleveland, unwilling, lix, berwick, catamaran, nazareth, conte, eridanus,
# Nearest to into: kword, reinforced, crossings, anabolic, seed, commence, besht, dnieper,
# Nearest to history: aristocratic, jourdain, exodus, salonika, matti, chicano, zealot, secretions,
# Nearest to by: enters, crucible, wholesome, enthusiastic, whiteman, haigh, subjection, irix,
# Nearest to many: multilevel, multicolored, ordination, behaviour, mnt, gurus, linked, magnitudes,
# Nearest to an: ladd, differently, expels, externally, lip, eleanor, binet, debauchery,
# Nearest to this: za, profited, melanesian, anfa, vigor, captives, gamma, attractive,
# Nearest to his: prosecution, offenses, beauregard, commited, sketchy, scholasticus, abercrombie, nero,
# Nearest to woman: malfeasance, refuting, facemask, pour, trouser, sudanic, residenz, polemical,
# Nearest to grand: welwyn, lawn, mesozoic, barrington, fishman, brownlow, paymaster, ecologist,
# Nearest to shows: recurring, validation, sounding, toonami, nintendo, behistun, leng, stateside,
# Nearest to brother: widow, humorist, castletown, cousin, duchess, terminally, helen, della,
# Nearest to articles: links, rediscovered, sigurd, lithographica, newcomb, mail, tithes, tolstoy,
# Nearest to running: fares, handled, franti, acknowledges, buck, feldspar, runequest, northridge,
# Nearest to marriage: mala, allah, pontifex, runge, kamehameha, ger, holy, tavern,
# Nearest to governor: gutted, cabriolet, cabinet, amputation, appointed, suburb, queen, nattiez,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 3.9369 0.2012 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 3.9077 0.1982 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 3.9890 0.1968 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.0195 0.1976 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 3.9872 0.1985 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 3.8911 0.1972 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 3.8876 0.1995 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 3.9656 0.1994 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 3.8273 0.2016 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 3.9237 0.1980 sec/batch
# Nearest to after: cleveland, lix, unwilling, berwick, catamaran, eridanus, unexpired, actuated,
# Nearest to into: reinforced, kword, crossings, anabolic, seed, commence, dnieper, besht,
# Nearest to history: jourdain, salonika, aristocratic, chicano, exodus, matti, bogdan, secretions,
# Nearest to by: enters, crucible, wholesome, whiteman, enthusiastic, haigh, irix, blueprints,
# Nearest to many: multilevel, multicolored, magnitudes, gurus, dispenser, ordination, behaviour, linked,
# Nearest to an: ladd, expels, jean, externally, eleanor, differently, dearest, sundials,
# Nearest to this: za, profited, melanesian, anfa, vigor, captives, gamma, attractive,
# Nearest to his: prosecution, beauregard, offenses, sketchy, abercrombie, commited, scholasticus, nero,
# Nearest to woman: malfeasance, refuting, facemask, polemical, sudanic, residenz, chorus, pour,
# Nearest to grand: lawn, welwyn, mesozoic, fishman, barrington, paymaster, aer, ecologist,
# Nearest to shows: toonami, recurring, nintendo, sounding, validation, behistun, leng, wills,
# Nearest to brother: widow, duchess, castletown, humorist, cousin, baird, helen, terminally,
# Nearest to articles: links, rediscovered, lithographica, sigurd, newcomb, chapters, mail, tithes,
# Nearest to running: fares, franti, handled, acknowledges, runequest, feldspar, northridge, buck,
# Nearest to marriage: mala, allah, kamehameha, pontifex, ger, tavern, consciences, objections,
# Nearest to governor: gutted, cabriolet, cabinet, appointed, amputation, willard, queen, stranglers,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 3.9159 0.2007 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 3.9044 0.1980 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 3.9508 0.0869 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 3.8704 0.1971 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 3.8675 0.1981 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 3.8453 0.1975 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 3.8335 0.1976 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 3.8246 0.1968 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 3.8247 0.1995 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 3.7758 0.1991 sec/batch
# Nearest to after: cleveland, lix, unwilling, berwick, catamaran, unexpired, actuated, conquistadores,
# Nearest to into: kword, anabolic, seed, reinforced, crossings, dnieper, commence, besht,
# Nearest to history: salonika, jourdain, aristocratic, matti, bogdan, exodus, chicano, glasnevin,
# Nearest to by: enters, crucible, wholesome, whiteman, haigh, irix, coughing, enthusiastic,
# Nearest to many: multilevel, counters, multicolored, magnitudes, ordination, typefaces, gurus, talkers,
# Nearest to an: ladd, eleanor, sundials, expels, dearest, jean, watcher, differently,
# Nearest to this: za, profited, melanesian, anfa, vigor, gamma, captives, favorite,
# Nearest to his: beauregard, prosecution, sketchy, scholasticus, commited, offenses, abercrombie, nero,
# Nearest to woman: malfeasance, refuting, facemask, polemical, chorus, trouser, sudanic, residenz,
# Nearest to grand: welwyn, mesozoic, lawn, barrington, fishman, paymaster, ecologist, aer,
# Nearest to shows: toonami, sounding, recurring, nintendo, validation, behistun, wills, handkerchief,
# Nearest to brother: duchess, widow, cousin, castletown, terminally, niece, voris, humorist,
# Nearest to articles: links, lithographica, rediscovered, anthroposophy, htm, tithes, newcomb, encyclopedia,
# Nearest to running: fares, handled, franti, runequest, feldspar, selamat, northridge, acknowledges,
# Nearest to marriage: allah, mala, kamehameha, consciences, pontifex, ger, tavern, flatt,
# Nearest to governor: cabriolet, gutted, appointed, cabinet, queen, willard, amputation, apollonia,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 3.8849 0.2008 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 3.8351 0.1984 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 3.8386 0.1994 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 3.7751 0.1978 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 3.7954 0.1990 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 3.7976 0.2004 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 3.7649 0.1996 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 3.8045 0.1989 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 3.8346 0.1991 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 3.7975 0.1989 sec/batch
# Nearest to after: cleveland, unwilling, lix, actuated, gibbous, rrna, cambyses, conquistadores,
# Nearest to into: anabolic, kword, seed, dnieper, reinforced, crossings, commence, attaches,
# Nearest to history: salonika, bogdan, jourdain, chicano, aristocratic, matti, exodus, glasnevin,
# Nearest to by: crucible, wholesome, enters, coughing, irix, haigh, whiteman, circulate,
# Nearest to many: multilevel, counters, multicolored, magnitudes, typefaces, mnt, dispenser, linked,
# Nearest to an: ladd, eleanor, expels, sundials, differently, deutschland, quill, externally,
# Nearest to this: za, profited, melanesian, anfa, gamma, aarseth, vigor, attractive,
# Nearest to his: prosecution, sketchy, offenses, nero, commited, beauregard, pertains, abercrombie,
# Nearest to woman: malfeasance, refuting, facemask, chorus, polemical, suppers, sheaths, pierluigi,
# Nearest to grand: welwyn, mesozoic, lawn, barrington, paymaster, aer, rumour, sor,
# Nearest to shows: toonami, validation, sounding, recurring, behistun, nintendo, stateside, rugians,
# Nearest to brother: widow, duchess, castletown, cousin, terminally, niece, voris, rowman,
# Nearest to articles: links, lithographica, rediscovered, tithes, htm, anthroposophy, encyclopedia, chapters,
# Nearest to running: fares, handled, runequest, franti, feldspar, roshan, selamat, acknowledges,
# Nearest to marriage: allah, mala, kamehameha, flatt, consciences, pontifex, antichrist, dowager,
# Nearest to governor: cabriolet, gutted, appointed, cabinet, willard, amputation, queen, disabled,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 3.7861 0.2006 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 3.8454 0.1981 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 3.7814 0.1987 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 3.7795 0.2005 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 3.7896 0.1995 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 3.7881 0.1999 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 3.8056 0.1982 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 3.7184 0.1980 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 3.7638 0.1978 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 3.8093 0.1978 sec/batch
# Nearest to after: cleveland, unwilling, lix, conquistadores, gibbous, rrna, berwick, mms,
# Nearest to into: anabolic, kword, dnieper, seed, reinforced, realschule, attaches, crossings,
# Nearest to history: salonika, bogdan, jourdain, chicano, matti, glasnevin, collecting, exodus,
# Nearest to by: crucible, wholesome, enters, coughing, irix, whiteman, haigh, circulate,
# Nearest to many: multilevel, alia, linked, multicolored, counters, ordination, talkers, mnt,
# Nearest to an: ladd, binet, eleanor, externally, dearest, expels, deutschland, jean,
# Nearest to this: za, profited, melanesian, anfa, vigor, aarseth, potters, captives,
# Nearest to his: prosecution, sketchy, commited, nero, pertains, abercrombie, offenses, autobiographical,
# Nearest to woman: malfeasance, refuting, facemask, fertility, pierluigi, suppers, chorus, sheaths,
# Nearest to grand: welwyn, mesozoic, lawn, barrington, sor, rumour, fishman, aer,
# Nearest to shows: toonami, validation, recurring, sounding, behistun, nintendo, rugians, reheat,
# Nearest to brother: widow, duchess, castletown, cousin, terminally, voris, naumburg, niece,
# Nearest to articles: links, lithographica, rediscovered, htm, encyclopedia, tithes, anthroposophy, chapters,
# Nearest to running: fares, runequest, handled, franti, climax, northridge, chatter, buck,
# Nearest to marriage: allah, mala, kamehameha, flatt, consciences, dowager, antichrist, pontifex,
# Nearest to governor: cabriolet, appointed, gutted, cabinet, democratically, amputation, disabled, willard,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 3.8095 0.2016 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 3.8106 0.1985 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 3.8051 0.1974 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 3.8119 0.1983 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 3.7671 0.2007 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 3.7619 0.1996 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 3.7997 0.1993 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 3.7691 0.1991 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 3.8193 0.1997 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 3.8371 0.1994 sec/batch
# Nearest to after: cleveland, unwilling, gibbous, lix, conquistadores, westchester, lurid, relena,
# Nearest to into: kword, anabolic, dnieper, reinforced, seed, diligence, realschule, napkin,
# Nearest to history: jourdain, salonika, bogdan, glasnevin, matti, chicano, exodus, ammonites,
# Nearest to by: crucible, haigh, enters, irix, wholesome, coughing, subjection, collectivist,
# Nearest to many: multilevel, alia, multicolored, ordination, carbondale, talkers, counters, linked,
# Nearest to an: ladd, eleanor, dearest, jean, binet, quill, courthouse, deutschland,
# Nearest to this: za, profited, melanesian, anfa, aarseth, favorite, captives, vigor,
# Nearest to his: prosecution, sketchy, nero, beauregard, commited, abercrombie, autobiographical, pertains,
# Nearest to woman: malfeasance, fertility, refuting, pierluigi, suppers, facemask, obito, artemis,
# Nearest to grand: welwyn, mesozoic, lawn, barrington, sor, fishman, rumour, porsche,
# Nearest to shows: toonami, validation, behistun, recurring, sounding, nintendo, rugians, purveyor,
# Nearest to brother: duchess, widow, cousin, castletown, niece, terminally, naumburg, rejoiced,
# Nearest to articles: links, lithographica, rediscovered, htm, tithes, anthroposophy, chapters, encyclopedia,
# Nearest to running: fares, handled, runequest, franti, northridge, echo, selamat, chatter,
# Nearest to marriage: kamehameha, mala, flatt, allah, consciences, objections, malfeasance, monogamy,
# Nearest to governor: cabriolet, gutted, appointed, cabinet, queen, amputation, apollonia, willard,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 3.8344 0.2032 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 3.7565 0.1986 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 3.7395 0.1989 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 3.7549 0.1999 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.6711 0.1983 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 3.7446 0.1990 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 3.7562 0.1979 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 3.7619 0.1981 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 3.7934 0.0322 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 3.7479 0.1988 sec/batch
# Nearest to after: unwilling, cleveland, crowding, gibbous, conquistadores, actuated, rrna, relena,
# Nearest to into: anabolic, kword, dnieper, meteor, attaches, realschule, reinforced, seed,
# Nearest to history: bogdan, salonika, glasnevin, jourdain, chicano, exodus, matti, collecting,
# Nearest to by: crucible, enters, haigh, irix, coughing, wholesome, collectivist, escorting,
# Nearest to many: multilevel, alia, counters, multicolored, talkers, carbondale, clarabelle, qattara,
# Nearest to an: ladd, eleanor, dearest, dobbs, jean, watcher, binet, deutschland,
# Nearest to this: za, profited, anfa, melanesian, aarseth, favorite, produced, vigor,
# Nearest to his: prosecution, sketchy, pertains, autobiographical, nero, commited, beauregard, scholasticus,
# Nearest to woman: malfeasance, fertility, refuting, facemask, suppers, chorus, obito, pierluigi,
# Nearest to grand: mesozoic, welwyn, lawn, barrington, sor, counties, porsche, fishman,
# Nearest to shows: toonami, validation, behistun, recurring, sounding, reheat, jabberwocky, purveyor,
# Nearest to brother: duchess, widow, cousin, castletown, niece, naumburg, terminally, armigerous,
# Nearest to articles: links, lithographica, rediscovered, htm, tithes, anthroposophy, chapters, encyclopedia,
# Nearest to running: fares, handled, runequest, franti, echo, chatter, selamat, climax,
# Nearest to marriage: kamehameha, monogamy, flatt, objections, consciences, malfeasance, mala, allah,
# Nearest to governor: cabriolet, appointed, gutted, cabinet, queen, apollonia, kerr, amputation,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 3.7157 0.2003 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 3.6854 0.1975 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 3.6944 0.1980 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.6712 0.1978 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 3.6586 0.1991 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.6672 0.1980 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.7014 0.1986 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 3.7084 0.1974 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 3.7369 0.1995 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.6410 0.1984 sec/batch
# Nearest to after: unwilling, cleveland, gibbous, relena, crowding, actuated, lurid, conquistadores,
# Nearest to into: anabolic, kword, attaches, dnieper, seed, reinforced, diligence, meteor,
# Nearest to history: bogdan, jourdain, collecting, salonika, glasnevin, chicano, exodus, basques,
# Nearest to by: crucible, enters, haigh, irix, wholesome, coughing, circulate, divestment,
# Nearest to many: multilevel, alia, counters, clarabelle, multicolored, carbondale, talkers, linked,
# Nearest to an: ladd, eleanor, dearest, binet, deutschland, externally, watcher, quill,
# Nearest to this: za, anfa, profited, aarseth, melanesian, produced, dyrrhachium, favorite,
# Nearest to his: prosecution, sketchy, pertains, nero, autobiographical, beauregard, commited, scholasticus,
# Nearest to woman: malfeasance, refuting, fertility, facemask, artemis, suppers, chorus, sheaths,
# Nearest to grand: mesozoic, welwyn, barrington, sor, lawn, counties, porsche, loose,
# Nearest to shows: toonami, validation, behistun, recurring, sounding, reheat, aired, jabberwocky,
# Nearest to brother: widow, duchess, cousin, castletown, niece, terminally, exports, armigerous,
# Nearest to articles: lithographica, links, rediscovered, htm, tithes, anthroposophy, sihanoukville, danio,
# Nearest to running: fares, runequest, handled, franti, chatter, climax, northridge, echo,
# Nearest to marriage: kamehameha, monogamy, flatt, mala, consciences, objections, unlawful, allah,
# Nearest to governor: appointed, cabriolet, cabinet, gutted, queen, apollonia, stranglers, amputation,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.6522 0.2028 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.6496 0.1998 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.6214 0.1994 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.6685 0.1986 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.6977 0.1984 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.6876 0.2009 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.6754 0.1989 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 3.7262 0.1991 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.6845 0.1979 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.6700 0.2033 sec/batch
# Nearest to after: unwilling, cleveland, relena, lurid, gibbous, conquistadores, crowding, rrna,
# Nearest to into: anabolic, kword, attaches, dnieper, reinforced, seed, diligence, bentinck,
# Nearest to history: bogdan, jourdain, collecting, salonika, glasnevin, chicano, ammonites, exodus,
# Nearest to by: crucible, enters, haigh, coughing, synaptic, irix, wholesome, divestment,
# Nearest to many: multilevel, alia, counters, multicolored, carbondale, linked, talkers, mnt,
# Nearest to an: binet, ladd, eleanor, dobbs, aengus, deutschland, externally, watcher,
# Nearest to this: za, profited, aarseth, anfa, produced, favorite, gamma, kilojoules,
# Nearest to his: sketchy, prosecution, autobiographical, pertains, nero, commited, scholasticus, abercrombie,
# Nearest to woman: malfeasance, facemask, chorus, refuting, artemis, suppers, submarine, fertility,
# Nearest to grand: mesozoic, welwyn, barrington, sor, lawn, porsche, counties, fishman,
# Nearest to shows: toonami, behistun, validation, recurring, reheat, aired, purveyor, sounding,
# Nearest to brother: widow, duchess, cousin, castletown, niece, armigerous, terminally, rejoiced,
# Nearest to articles: rediscovered, lithographica, links, htm, anthroposophy, tithes, reviews, danio,
# Nearest to running: fares, runequest, handled, franti, climax, echo, northridge, buck,
# Nearest to marriage: monogamy, kamehameha, flatt, unlawful, consciences, objections, ayckbourn, dowager,
# Nearest to governor: cabriolet, appointed, gutted, cabinet, queen, amputation, apollonia, hearings,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.6727 0.2014 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 3.7228 0.1989 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.6767 0.1995 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.6612 0.1983 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 3.6764 0.1978 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 3.6736 0.1976 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 3.6909 0.1969 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.6722 0.1985 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.7022 0.1983 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.7232 0.1990 sec/batch
# Nearest to after: unwilling, conquistadores, relena, cleveland, lurid, gibbous, rrna, crowding,
# Nearest to into: attaches, anabolic, kword, dnieper, seed, reinforced, diligence, bentinck,
# Nearest to history: bogdan, jourdain, salonika, glasnevin, matti, ammonites, exodus, chicano,
# Nearest to by: crucible, enters, haigh, escorting, coughing, divestment, circulate, subjection,
# Nearest to many: multilevel, alia, talkers, multicolored, carbondale, descriptors, counters, mnt,
# Nearest to an: ladd, eleanor, binet, dobbs, dearest, hif, aengus, jean,
# Nearest to this: za, profited, aarseth, produced, anfa, vigor, captives, favorite,
# Nearest to his: sketchy, prosecution, nero, autobiographical, pertains, heartland, commited, chastised,
# Nearest to woman: malfeasance, fertility, chorus, obito, suppers, adult, artemis, refuting,
# Nearest to grand: welwyn, mesozoic, barrington, counties, porsche, prix, sor, lawn,
# Nearest to shows: toonami, behistun, validation, recurring, reheat, aired, proterozoic, purveyor,
# Nearest to brother: widow, duchess, cousin, castletown, niece, terminally, armigerous, claimants,
# Nearest to articles: lithographica, rediscovered, anthroposophy, tithes, links, sihanoukville, htm, danio,
# Nearest to running: runequest, fares, handled, climax, franti, selamat, northridge, chatter,
# Nearest to marriage: monogamy, kamehameha, flatt, unlawful, consciences, decays, abdominal, ayckbourn,
# Nearest to governor: cabriolet, appointed, gutted, queen, cabinet, amputation, kerr, apollonia,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.6821 0.2038 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.6545 0.2003 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.6455 0.1997 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 3.7018 0.2002 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 3.6964 0.1988 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 3.7538 0.1980 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 3.7364 0.1994 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.6554 0.1988 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.6579 0.1994 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.6681 0.1986 sec/batch
# Nearest to after: unwilling, relena, gibbous, conquistadores, lurid, cleveland, crowding, rrna,
# Nearest to into: attaches, anabolic, seed, dnieper, reinforced, kword, realschule, abdali,
# Nearest to history: bogdan, salonika, jourdain, glasnevin, collecting, chicano, exodus, ammonites,
# Nearest to by: crucible, enters, haigh, coughing, escorting, irix, collectivist, synaptic,
# Nearest to many: multilevel, alia, carbondale, counters, talkers, multicolored, descriptors, criollo,
# Nearest to an: eleanor, ladd, dobbs, binet, dearest, aengus, jean, hif,
# Nearest to this: za, anfa, profited, produced, aarseth, favorite, gamma, captives,
# Nearest to his: autobiographical, sketchy, prosecution, pertains, nero, chastised, scholasticus, commited,
# Nearest to woman: malfeasance, fertility, submarine, male, adult, chorus, suppers, artemis,
# Nearest to grand: counties, barrington, welwyn, mesozoic, porsche, prix, sor, lion,
# Nearest to shows: toonami, behistun, validation, recurring, reheat, aired, attraction, purveyor,
# Nearest to brother: widow, duchess, cousin, castletown, niece, claimants, armigerous, naumburg,
# Nearest to articles: lithographica, rediscovered, tithes, anthroposophy, sihanoukville, links, danio, htm,
# Nearest to running: runequest, fares, climax, handled, franti, selamat, echo, northridge,
# Nearest to marriage: monogamy, kamehameha, flatt, abdominal, dowager, unlawful, decays, ayckbourn,
# Nearest to governor: cabriolet, appointed, gutted, queen, kerr, cabinet, apollonia, amputation,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.6070 0.2019 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.6430 0.1994 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.6670 0.1987 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.6400 0.1981 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 3.6983 0.1988 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.6696 0.1744 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.6237 0.1988 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.6228 0.1974 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.6196 0.1983 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.5751 0.1976 sec/batch
# Nearest to after: unwilling, relena, gibbous, conquistadores, cleveland, lurid, rrna, crowding,
# Nearest to into: attaches, anabolic, seed, dnieper, kword, reinforced, meteor, realschule,
# Nearest to history: bogdan, collecting, jourdain, salonika, glasnevin, ammonites, tracking, resumption,
# Nearest to by: crucible, haigh, enters, synaptic, coughing, irix, collectivist, circulate,
# Nearest to many: multilevel, alia, criollo, clarabelle, counters, multicolored, carbondale, mnt,
# Nearest to an: eleanor, aengus, binet, dobbs, dearest, superstitious, ladd, housework,
# Nearest to this: za, produced, profited, favorite, anfa, aarseth, dyrrhachium, muni,
# Nearest to his: sketchy, autobiographical, prosecution, scholasticus, heartland, pertains, nero, chastised,
# Nearest to woman: malfeasance, fertility, artemis, submarine, chorus, male, refuting, adult,
# Nearest to grand: welwyn, barrington, prix, counties, mesozoic, porsche, sor, lion,
# Nearest to shows: toonami, behistun, validation, recurring, purveyor, aired, reheat, jabberwocky,
# Nearest to brother: widow, cousin, niece, duchess, castletown, armigerous, rejoiced, claimants,
# Nearest to articles: lithographica, anthroposophy, tithes, rediscovered, links, sihanoukville, htm, danio,
# Nearest to running: runequest, handled, fares, climax, feldspar, selamat, echo, dec,
# Nearest to marriage: monogamy, kamehameha, abdominal, flatt, married, unlawful, consciences, ayckbourn,
# Nearest to governor: cabriolet, gutted, appointed, queen, kerr, amputation, apollonia, cabinet,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.6113 0.2019 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.5545 0.1996 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.6305 0.1976 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.6440 0.1987 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.6273 0.2009 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.6546 0.1989 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.5372 0.2018 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.6052 0.1999 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.5504 0.1999 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.5902 0.1996 sec/batch
# Nearest to after: relena, unwilling, gibbous, conquistadores, rrna, crowding, cleveland, lurid,
# Nearest to into: anabolic, attaches, dnieper, meteor, reinforced, kword, sanitization, seed,
# Nearest to history: bogdan, collecting, jourdain, salonika, ammonites, glasnevin, libels, tracking,
# Nearest to by: crucible, haigh, synaptic, enters, irix, coughing, collectivist, escorting,
# Nearest to many: multilevel, criollo, clarabelle, alia, counters, mnt, multicolored, talkers,
# Nearest to an: eleanor, aengus, binet, dobbs, ladd, superstitious, jean, housework,
# Nearest to this: za, dyrrhachium, aarseth, kilojoules, profited, produced, captives, anfa,
# Nearest to his: sketchy, autobiographical, pertains, prosecution, scholasticus, heartland, reputation, garnett,
# Nearest to woman: malfeasance, fertility, artemis, male, refuting, adult, chorus, submarine,
# Nearest to grand: welwyn, barrington, prix, mesozoic, counties, porsche, sor, magnetopause,
# Nearest to shows: toonami, validation, behistun, recurring, aired, reheat, purveyor, riviera,
# Nearest to brother: widow, cousin, castletown, rejoiced, duchess, armigerous, exports, naumburg,
# Nearest to articles: lithographica, tithes, rediscovered, anthroposophy, sihanoukville, htm, danio, links,
# Nearest to running: runequest, climax, handled, fares, feldspar, franti, chatter, northridge,
# Nearest to marriage: monogamy, abdominal, decays, kamehameha, flatt, married, ayckbourn, dowager,
# Nearest to governor: cabriolet, appointed, gutted, queen, kerr, cabinet, senate, hearings,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.6303 0.2030 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.6173 0.1978 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.5654 0.1995 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.6491 0.1986 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.6341 0.2004 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.5680 0.1990 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.6204 0.1992 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.6129 0.2010 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.6067 0.1986 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.6122 0.2002 sec/batch
# Nearest to after: relena, unwilling, gibbous, rrna, conquistadores, lurid, crowding, cleveland,
# Nearest to into: anabolic, attaches, diligence, dnieper, reinforced, realschule, meteor, sanitization,
# Nearest to history: bogdan, collecting, jourdain, salonika, ammonites, glasnevin, resumption, libels,
# Nearest to by: crucible, haigh, synaptic, coughing, enters, irix, escorting, collectivist,
# Nearest to many: multilevel, alia, criollo, clarabelle, mnt, multicolored, carbondale, surged,
# Nearest to an: eleanor, dobbs, binet, ladd, aengus, hif, watcher, cfc,
# Nearest to this: za, profited, favorite, aarseth, dyrrhachium, kilojoules, produced, leiber,
# Nearest to his: autobiographical, sketchy, pertains, reputation, prosecution, dallas, heartland, contemporaries,
# Nearest to woman: malfeasance, fertility, artemis, male, adult, submarine, refuting, chorus,
# Nearest to grand: prix, welwyn, barrington, counties, porsche, mesozoic, sor, magnetopause,
# Nearest to shows: toonami, validation, aired, behistun, recurring, riviera, attraction, purveyor,
# Nearest to brother: widow, cousin, castletown, duchess, armigerous, rejoiced, claimants, niece,
# Nearest to articles: lithographica, rediscovered, links, htm, anthroposophy, tithes, sihanoukville, reviews,
# Nearest to running: runequest, climax, handled, fares, northridge, franti, conspires, chatter,
# Nearest to marriage: monogamy, flatt, decays, abdominal, kamehameha, married, ayckbourn, dowager,
# Nearest to governor: cabriolet, appointed, gutted, kerr, queen, senate, cabinet, hearings,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.6371 0.2004 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.6338 0.1982 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.6102 0.1988 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.6039 0.1977 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.6387 0.1982 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.6237 0.1976 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.6164 0.1990 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.5938 0.1993 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.5685 0.2000 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.6401 0.1993 sec/batch
# Nearest to after: relena, conquistadores, gibbous, unwilling, lurid, rrna, crowding, cleveland,
# Nearest to into: anabolic, attaches, dnieper, diligence, reinforced, abdali, meteor, realschule,
# Nearest to history: bogdan, jourdain, collecting, salonika, ammonites, resumption, matti, glasnevin,
# Nearest to by: crucible, haigh, enters, coughing, synaptic, divestment, trouv, irix,
# ...
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.4371 0.2022 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.4682 0.2038 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.4645 0.2031 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.4728 0.2032 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.4890 0.2035 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.4808 0.2029 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.4899 0.2030 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.4962 0.2018 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.4649 0.2034 sec/batch
# Nearest to after: gibbous, relena, conquistadores, rrna, lurid, dissolved, toonami, unwilling,
# Nearest to into: divided, attaches, anabolic, legrand, abdali, subdivided, sprachen, normalization,
# Nearest to history: collecting, outbreaks, resumption, timeline, ammonites, bogdan, glasnevin, libels,
# Nearest to by: structuring, crucible, utero, cornwall, wooden, trouv, affinity, escorting,
# Nearest to many: multilevel, gathered, surged, criollo, disagree, bloated, testimonials, supra,
# Nearest to an: dobbs, aengus, cfc, binet, rowena, handicrafts, procedural, superstitious,
# Nearest to this: dyrrhachium, convergent, bristol, newspaperman, metabolised, muni, hydrogen, postponed,
# Nearest to his: heartland, autobiographical, agra, inwo, supplant, bordeaux, geraldine, niclas,
# Nearest to woman: bps, expectancy, nationality, fertility, spouse, develops, unintelligent, pregnancy,
# Nearest to grand: prix, porsche, counties, chairmanship, barrington, spokeswoman, muscovy, peerage,
# Nearest to shows: toonami, attraction, periods, behistun, riviera, validation, animating, aired,
# Nearest to brother: widow, cousin, claimants, castletown, turn, aquileia, son, barks,
# Nearest to articles: sihanoukville, links, lithographica, danio, htm, aquaculture, soc, someday,
# Nearest to running: runequest, climax, handled, buck, susquehanna, successors, dec, conspires,
# Nearest to marriage: dowager, monogamy, polyamory, married, ayckbourn, decays, rammstein, homeomorphisms,
# Nearest to governor: senate, kerr, appointed, appoint, advised, excellency, queen, hearings,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.4872 0.2058 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.4675 0.2041 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.4814 0.2023 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.4770 0.2022 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.5130 0.2028 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.4560 0.2031 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.5918 0.2025 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.5255 0.2001 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.5442 0.2009 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.4500 0.2017 sec/batch
# Nearest to after: gibbous, relena, conquistadores, dissolved, unwilling, toonami, rrna, lurid,
# Nearest to into: divided, anabolic, attaches, abdali, legrand, subdivided, meteor, detachable,
# Nearest to history: collecting, outbreaks, resumption, ammonites, timeline, dope, libels, bogdan,
# Nearest to by: escorting, wooden, crucible, utero, affinity, structuring, skimming, haigh,
# Nearest to many: multilevel, criollo, gathered, surged, disagree, testimonials, bloated, nidal,
# Nearest to an: dobbs, aengus, rowena, cfc, brahms, costas, binet, handicrafts,
# Nearest to this: dyrrhachium, newspaperman, postponed, metabolised, convergent, muni, hydrogen, anymore,
# Nearest to his: heartland, autobiographical, inwo, opioid, agra, supplant, pharmacists, geraldine,
# Nearest to woman: expectancy, bps, nationality, fertility, spouse, unintelligent, male, adjective,
# Nearest to grand: prix, counties, porsche, barrington, muscovy, chairmanship, auto, peerage,
# Nearest to shows: toonami, periods, attraction, behistun, riviera, validation, whispers, connectedness,
# Nearest to brother: widow, claimants, cousin, castletown, turn, aquileia, pleadings, terminally,
# Nearest to articles: sihanoukville, links, lithographica, danio, someday, htm, aquaculture, anthroposophy,
# Nearest to running: runequest, climax, susquehanna, handled, dec, buck, successors, defensive,
# Nearest to marriage: dowager, monogamy, polyamory, married, ayckbourn, polyandry, decays, pregnancies,
# Nearest to governor: kerr, senate, advised, excellency, queen, appointed, hearings, appoint,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.3996 0.2063 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.4815 0.2022 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.4152 0.2033 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.4876 0.2027 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.4547 0.2048 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.4427 0.2040 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.5114 0.0986 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.4265 0.2031 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.4259 0.2026 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.4514 0.2018 sec/batch
# Nearest to after: gibbous, relena, conquistadores, toonami, unwilling, rrna, lurid, crowding,
# Nearest to into: divided, anabolic, attaches, abdali, legrand, subdivided, meteor, normalization,
# Nearest to history: collecting, outbreaks, resumption, ammonites, timeline, bogdan, dope, libels,
# Nearest to by: escorting, utero, crucible, trouv, wooden, affinity, cornwall, haigh,
# Nearest to many: multilevel, gathered, surged, criollo, disagree, testimonials, bloated, supra,
# Nearest to an: dobbs, aengus, rowena, cfc, brahms, hoisted, binet, syrian,
# Nearest to this: dyrrhachium, days, newspaperman, bristol, convergent, leiber, postponed, captives,
# Nearest to his: heartland, agra, autobiographical, opioid, inwo, immovable, bordeaux, father,
# Nearest to woman: expectancy, nationality, bps, spouse, fertility, unintelligent, pregnancy, male,
# Nearest to grand: prix, counties, porsche, muscovy, auto, barrington, spokeswoman, racing,
# Nearest to shows: toonami, periods, attraction, behistun, validation, whispers, embodiment, riviera,
# Nearest to brother: widow, cousin, claimants, turn, castletown, aquileia, son, dugan,
# Nearest to articles: sihanoukville, lithographica, links, aquaculture, danio, htm, anthroposophy, rada,
# Nearest to running: runequest, climax, handled, susquehanna, successors, dec, defensive, buck,
# Nearest to marriage: dowager, monogamy, married, polyamory, polyandry, ayckbourn, marriages, pregnancies,
# Nearest to governor: kerr, senate, hearings, advised, excellency, appointed, queen, lieutenant,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.4479 0.2037 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.4471 0.2018 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.4354 0.2021 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.4096 0.2037 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.4777 0.2040 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.4549 0.2048 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.4691 0.2031 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.4226 0.2042 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.4295 0.2056 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.4067 0.2041 sec/batch
# Nearest to after: gibbous, relena, conquistadores, toonami, rrna, scientist, lurid, crowding,
# Nearest to into: divided, anabolic, attaches, legrand, subdivided, rte, abdali, meteor,
# Nearest to history: collecting, outbreaks, resumption, timeline, ammonites, libels, daemen, pluralism,
# Nearest to by: utero, crucible, wooden, escorting, trouv, structuring, cornwall, affinity,
# Nearest to many: multilevel, gathered, criollo, surged, testimonials, disagree, nidal, bloated,
# Nearest to an: dobbs, cfc, handicrafts, rowena, aengus, brahms, hoisted, syrian,
# Nearest to this: dyrrhachium, days, captives, convergent, bristol, hydrogen, newspaperman, discoid,
# Nearest to his: heartland, agra, inwo, autobiographical, supplant, pharmacists, geraldine, nammu,
# Nearest to woman: bps, expectancy, spouse, nationality, fertility, develops, unintelligent, pregnancy,
# Nearest to grand: prix, counties, porsche, muscovy, barrington, knights, auto, spokeswoman,
# Nearest to shows: toonami, periods, attraction, behistun, validation, embodiment, riviera, connectedness,
# Nearest to brother: widow, cousin, claimants, turn, castletown, aquileia, dugan, son,
# Nearest to articles: sihanoukville, links, lithographica, aquaculture, danio, htm, anthroposophy, rada,
# Nearest to running: runequest, climax, susquehanna, defensive, handled, successors, buck, dec,
# Nearest to marriage: dowager, monogamy, polyamory, married, polyandry, ayckbourn, marriages, pregnancies,
# Nearest to governor: senate, kerr, appointed, excellency, hearings, advised, appoint, queen,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.3586 0.2063 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.4265 0.2038 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.4817 0.2025 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.4380 0.2014 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.4114 0.2033 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.4989 0.2009 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.4761 0.2023 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.4223 0.2028 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.4487 0.2020 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.4455 0.2039 sec/batch
# Nearest to after: gibbous, relena, toonami, conquistadores, rrna, lurid, cancelled, ripening,
# Nearest to into: divided, anabolic, attaches, subdivided, legrand, rte, abdali, musicum,
# Nearest to history: collecting, outbreaks, resumption, timeline, ammonites, libels, pluralism, dope,
# Nearest to by: crucible, escorting, utero, cornwall, wooden, trouv, skimming, structuring,
# Nearest to many: multilevel, gathered, surged, criollo, testimonials, disagree, nidal, supra,
# Nearest to an: dobbs, cfc, handicrafts, aengus, hoisted, rowena, brahms, baker,
# Nearest to this: dyrrhachium, days, bristol, convergent, newspaperman, metabolised, captives, postponed,
# Nearest to his: heartland, autobiographical, supplant, agra, geraldine, inwo, opioid, father,
# Nearest to woman: bps, expectancy, spouse, nationality, fertility, develops, unintelligent, male,
# Nearest to grand: prix, counties, porsche, barrington, spokeswoman, auto, muscovy, scuola,
# Nearest to shows: toonami, periods, attraction, validation, behistun, whispers, embodiment, connectedness,
# Nearest to brother: widow, cousin, claimants, turn, castletown, aquileia, dugan, son,
# Nearest to articles: sihanoukville, links, aquaculture, danio, lithographica, someday, anthroposophy, morbid,
# Nearest to running: runequest, climax, defensive, handled, susquehanna, successors, buck, rdos,
# Nearest to marriage: dowager, married, polyamory, monogamy, ayckbourn, polyandry, marriages, pregnancies,
# Nearest to governor: senate, kerr, appointed, excellency, hearings, appoint, advised, pics,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.5154 0.2060 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.4167 0.2018 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.4481 0.2028 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.4592 0.2008 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.5005 0.2022 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.4885 0.2019 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.4304 0.2008 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.4881 0.2023 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.4509 0.2048 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.4402 0.2043 sec/batch
# Nearest to after: gibbous, relena, toonami, conquistadores, rrna, lurid, scientist, ripening,
# Nearest to into: divided, anabolic, attaches, subdivided, abdali, detachable, legrand, forcibly,
# Nearest to history: outbreaks, collecting, timeline, resumption, ammonites, pluralism, libels, chronological,
# Nearest to by: crucible, utero, escorting, cornwall, wooden, trouv, structuring, skimming,
# Nearest to many: multilevel, gathered, surged, criollo, disagree, testimonials, villas, nidal,
# Nearest to an: dobbs, handicrafts, cfc, rowena, aengus, baker, costas, suppressive,
# Nearest to this: dyrrhachium, metabolised, days, convergent, hydrogen, bristol, discoid, cordless,
# Nearest to his: heartland, agra, autobiographical, supplant, geraldine, opioid, nammu, inwo,
# Nearest to woman: bps, spouse, nationality, expectancy, fertility, develops, unintelligent, adjective,
# Nearest to grand: prix, counties, porsche, peerage, muscovy, spokeswoman, cosimo, barrington,
# Nearest to shows: toonami, periods, attraction, behistun, validation, connectedness, riviera, eddies,
# Nearest to brother: widow, cousin, claimants, aquileia, turn, castletown, dugan, rescuers,
# Nearest to articles: sihanoukville, links, someday, danio, morbid, aquaculture, lithographica, kinney,
# Nearest to running: runequest, climax, susquehanna, successors, handled, buck, defensive, rdos,
# Nearest to marriage: dowager, married, polyamory, monogamy, polyandry, pregnancies, ayckbourn, marital,
# Nearest to governor: senate, kerr, appointed, excellency, appoint, advised, hearings, queen,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.4633 0.2071 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.4595 0.2034 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.5459 0.2037 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.5578 0.2046 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.4796 0.2037 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.4712 0.2048 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.4005 0.2024 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.4015 0.2016 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.3784 0.2022 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.4891 0.2056 sec/batch
# Nearest to after: gibbous, relena, toonami, conquistadores, scientist, rrna, lurid, instruments,
# Nearest to into: divided, anabolic, attaches, subdivided, abdali, detachable, mon, interstates,
# Nearest to history: outbreaks, collecting, resumption, timeline, ammonites, dope, pluralism, chronological,
# Nearest to by: utero, crucible, escorting, skimming, wooden, cornwall, structuring, haigh,
# Nearest to many: multilevel, gathered, criollo, surged, testimonials, disagree, villas, talkers,
# Nearest to an: dobbs, handicrafts, rowena, cfc, costas, baker, dependent, hoisted,
# Nearest to this: dyrrhachium, convergent, days, newspaperman, bristol, postponed, leiber, metabolised,
# Nearest to his: heartland, autobiographical, agra, inwo, geraldine, supplant, nammu, edwardian,
# Nearest to woman: bps, nationality, adjective, spouse, fertility, develops, unintelligent, expectancy,
# Nearest to grand: prix, counties, porsche, muscovy, cosimo, peerage, duchy, spokeswoman,
# Nearest to shows: toonami, periods, attraction, behistun, validation, whispers, connectedness, aired,
# Nearest to brother: widow, turn, claimants, cousin, dugan, castletown, aquileia, rescuers,
# Nearest to articles: sihanoukville, morbid, someday, links, aquaculture, danio, anthroposophy, lithographica,
# Nearest to running: runequest, climax, susquehanna, successors, handled, buck, dec, defensive,
# Nearest to marriage: dowager, married, polyamory, monogamy, ayckbourn, polyandry, pregnancies, marriages,
# Nearest to governor: senate, kerr, appointed, queen, advised, appoint, hearings, excellency,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.4683 0.2077 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.4612 0.2031 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
